# %% [markdown]
# # Обработка данных

# %% [markdown]
# ### Загрузка библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
# !pip install rdkit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 22.8 MB/s eta 0:00:00
# ...

# %%
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import AllChem, Draw, Descriptors
from rdkit.Chem.Draw import IPythonConsole
from sklearn.preprocessing import FunctionTransformer

# %% [markdown]
# ### Загрузка данных

# %%
df = pd.read_excel('1400.xlsx')
df
# Out:
#               Title  IC50, mmg/ml  CC50-MDCK, mmg/ml             SI  \
# 0       1007-Ya-213           2.7              500.0     185.185185
# 1       1007-Ya-213           0.7              447.0     638.571429
# 2       1008-Ya-187           9.9              144.0      14.545455
# 3       1009-As-106           8.3              500.0      60.240964
# 4       1010-Ya-208          39.4              143.0       3.629442
# ...             ...           ...                ...            ...
# 1463  CHEMBL4251117           7.3              530.6      72.800000
# 1464  CHEMBL4217515           3.8             4733.9    1250.000000
# 1465  CHEMBL4205814           0.3             4733.9   14285.700000
# 1466  CHEMBL4212064           0.7             3662.8    5555.600000
# 1467  CHEMBL4452992           0.1            37646.0  312500.000000
#
#       Molecular weight  Hydrogen bond acceptors  Hydrogen bond donors  \
# 0              195.307                        2                     1
# ...

# %%
df['SI'] = df['CC50-MDCK, mmg/ml']/df['IC50, mmg/ml']
df['S_leng'] = df['SMILES'].str.len ()
df.drop(columns = ['Pictures'],axis = 1, inplace=True)

# %%
df.head()
# Out:
#          Title  IC50, mmg/ml  CC50-MDCK, mmg/ml          SI  Molecular weight  \
# 0  1007-Ya-213           2.7              500.0  185.185185           195.307
# 1  1007-Ya-213           0.7              447.0  638.571429           195.307
# 2  1008-Ya-187           9.9              144.0   14.545455           250.431
# 3  1009-As-106           8.3              500.0   60.240964           222.377
# 4  1010-Ya-208          39.4              143.0    3.629442           239.361
#
#    Hydrogen bond acceptors  Hydrogen bond donors  Polar SA  \
# 0                        2                     1     32.59
# 1                        2                     1     32.59
# 2                        1                     0     15.60
# 3                        1                     0     15.60
# 4                        2                     0     29.54
#
#                                          SMILES  S_leng
# 0           OCC\N=C(\[C@]12C)C[C@@H](C1(C)C)CC2      35
# ...

# %%
df.describe()
# Out:
#        IC50, mmg/ml  CC50-MDCK, mmg/ml            SI  Molecular weight  \
# count   1468.000000        1468.000000  1.468000e+03       1468.000000
# mean      50.277063         186.491530  2.210854e+04        384.739636
# std       92.184768        1009.454293  4.771268e+05        153.164268
# min        0.000010           0.031928  3.616134e-02        110.157000
# 25%        2.500000          30.375000  1.833333e+00        283.049250
# 50%       10.100000          90.400000  5.528073e+00        349.371000
# 75%       49.450000         300.000000  2.778741e+01        446.508000
# max     1000.000000       37646.000000  1.632222e+07       1159.380000
#
#        Hydrogen bond acceptors  Hydrogen bond donors     Polar SA       S_leng
# count              1468.000000           1468.000000  1468.000000  1468.000000
# mean                  3.831744              1.333787    81.273215    62.997956
# std                   2.860473              1.803663    54.078778    32.373175
# ...

# %%
df.count()
# Out:
# Title                      1468
# IC50, mmg/ml               1468
# CC50-MDCK, mmg/ml          1468
# SI                         1468
# Molecular weight           1468
# Hydrogen bond acceptors    1468
# Hydrogen bond donors       1468
# Polar SA                   1468
# SMILES                     1468
# S_leng                     1468
# dtype: int64

# %%
df.columns
# Out:
# Index(['Title', 'IC50, mmg/ml', 'CC50-MDCK, mmg/ml', 'SI', 'Molecular weight',
#        'Hydrogen bond acceptors', 'Hydrogen bond donors', 'Polar SA', 'SMILES',
#        'S_leng'],
#       dtype='object')

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# Поскольку 75% данных приходится на 28,34, а максимальное значение равно 1 596 170, то попробуем оставить значения, которые меньше 500.

# %%
df1 = df[df['SI'] < 500]

# %%
# y = np.log(df1['SI'])
# sns.histplot(y)
sns.histplot(df1['SI'])
# Out:
# <Axes: xlabel='SI', ylabel='Count'>

# %% [markdown]
# Посмотрим на длину формул:

# %%
sns.histplot(df1['S_leng'])
# Out:
# <Axes: xlabel='S_leng', ylabel='Count'>

# %%
df[df['SI'] <500].count()
# Out:
# Title                      1371
# IC50, mmg/ml               1371
# CC50-MDCK, mmg/ml          1371
# SI                         1371
# Molecular weight           1371
# Hydrogen bond acceptors    1371
# Hydrogen bond donors       1371
# Polar SA                   1371
# SMILES                     1371
# S_leng                     1371
# dtype: int64

# %% [markdown]
# Соответственно, убираем 97 записей (это 6.6% от исходных данных)

# %%
sns.boxplot(df1['SI'])
# Out:
# <Axes: >

# %% [markdown]
# Однако на диаграмме размаха наблюдаются выбросы, поскольку большинство данных сконцентрированы в диапазоне от 0 до 50 (приблизительно).

# %%
df1.describe()
# Out:
#        IC50, mmg/ml  CC50-MDCK, mmg/ml           SI  Molecular weight  \
# count   1371.000000        1371.000000  1371.000000       1371.000000
# mean      53.824958         154.043812    23.898142        382.003716
# std       94.387839         157.995801    55.240843        153.854289
# min        0.000414           0.031928     0.036161        110.157000
# 25%        3.350000          30.000000     1.720285        280.858000
# 50%       12.000000          90.400000     4.787072        345.324000
# 75%       57.850000         300.000000    19.109069        441.158000
# max     1000.000000        1039.000000   499.500000       1159.380000
#
#        Hydrogen bond acceptors  Hydrogen bond donors     Polar SA       S_leng
# count              1371.000000           1371.000000  1371.000000  1371.000000
# mean                  3.769511              1.270605    77.858067    62.168490
# std                   2.840423              1.793867    52.794926    32.237871
# ...

# %%
df1.corr()
# Out:
# <ipython-input-16-49b3fcfeb4d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                          IC50, mmg/ml  CC50-MDCK, mmg/ml        SI  \
# IC50, mmg/ml                 1.000000           0.479697 -0.217316
# CC50-MDCK, mmg/ml            0.479697           1.000000  0.124908
# SI                          -0.217316           0.124908  1.000000
# Molecular weight            -0.119945           0.010415  0.083460
# Hydrogen bond acceptors     -0.061520           0.028207  0.136730
# Hydrogen bond donors        -0.124046          -0.050898  0.130502
# Polar SA                    -0.044871          -0.050485  0.107515
# S_leng                      -0.101391           0.098504  0.104560
#
#                          Molecular weight  Hydrogen bond acceptors  \
# ...

# %% [markdown]
# SI незначительно коррелирует с Hydrogen bond donors и Hydrogen bond acceptors. SI зависим от IC50, что можно заметить на матрице корреляции.

# %% [markdown]
# #Дескриптор

# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import AllChem, Draw, Descriptors
from rdkit.Chem.Draw import IPythonConsole
from sklearn.preprocessing import FunctionTransformer

# %%
def mol_dsc_calc(mols):
    return pd.DataFrame({k: f(Chem.MolFromSmiles(m)) for k, f in descriptors.items()} for m in mols)

# список конституционных и физико-химических дескрипторов из библиотеки RDKit
descriptors = {"HeavyAtomCount": Descriptors.HeavyAtomCount,
               "NHOHCount": Descriptors.NHOHCount,
               "NOCount": Descriptors.NOCount,
               "NumHAфcceptors": Descriptors.NumHAcceptors,
               "NumHDonors": Descriptors.NumHDonors,
               "NumHeteroatoms": Descriptors.NumHeteroatoms,
               "NumRotatableBonds": Descriptors.NumRotatableBonds,
               "NumValenceElectrons": Descriptors.NumValenceElectrons,
               "NumAromaticRings": Descriptors.NumAromaticRings,
               "NumAliphaticHeterocycles": Descriptors.NumAliphaticHeterocycles,
               "RingCount": Descriptors.RingCount,
               "MW": Descriptors.MolWt,
               "LogP": Descriptors.MolLogP,
               "MR": Descriptors.MolMR,
               "TPSA": Descriptors.TPSA}

# sklearn трансформер для использования в конвейерном моделировании
descriptors_transformer = FunctionTransformer(mol_dsc_calc)
X = descriptors_transformer.transform(df['SMILES'])
X.head()
# Out:
# [10:25:04] Conflicting single bond directions around double bond at index 55.
# [10:25:04]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [10:25:04] Conflicting single bond directions around double bond at index 55.
# [10:25:04]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [10:25:04] Conflicting single bond directions around double bond at index 55.
# [10:25:04]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [10:25:04] Conflicting single bond directions around double bond at index 55.
# [10:25:04]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [10:25:04] Conflicting single bond directions around double bond at index 55.
# [10:25:04]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [10:25:04] Conflicting single bond directions around double bond at index 55.
# [10:25:04]   BondStereo set to STEREONONE and single bond directions set to NONE.
# ...

# %%
X.count()
# Out:
# HeavyAtomCount              1468
# NHOHCount                   1468
# NOCount                     1468
# NumHAфcceptors              1468
# NumHDonors                  1468
# NumHeteroatoms              1468
# NumRotatableBonds           1468
# NumValenceElectrons         1468
# NumAromaticRings            1468
# NumAliphaticHeterocycles    1468
# RingCount                   1468
# MW                          1468
# LogP                        1468
# MR                          1468
# TPSA                        1468
# dtype: int64

# %%
y = df1['SI'].values.reshape((-1,1))
scaler = MinMaxScaler()
y = scaler.fit_transform(y)
pd.DataFrame(y)
# y_test = scaler.transform(y_test)
# y_validation = scaler.transform(y_validation)
# Out:
#              0
# 0     0.370696
# 1     0.029050
# 2     0.120539
# 3     0.007194
# 4     0.038729
# ...        ...
# 1366  0.001930
# 1367  0.067925
# 1368  0.027499
# 1369  0.058997
# 1370  0.145454
#
# [1371 rows x 1 columns]

# %%
# df1 = df1.reset_index()
sample = df.iloc[:, 3]
sample
# Out:
# 0          185.185185
# 1          638.571429
# 2           14.545455
# 3           60.240964
# 4            3.629442
#             ...
# 1463        72.684932
# 1464      1245.763158
# 1465     15779.666667
# 1466      5232.571429
# 1467    376460.000000
# Name: SI, Length: 1468, dtype: float64

# %%
sample_full = pd.concat([sample, X], axis=1)

# %%
sample_full
# Out:
#                  SI  HeavyAtomCount  NHOHCount  NOCount  NumHAфcceptors  \
# 0        185.185185              14          1        2               2
# 1        638.571429              14          1        2               2
# 2         14.545455              18          0        2               2
# 3         60.240964              16          0        2               2
# 4          3.629442              17          0        3               3
# ...             ...             ...        ...      ...             ...
# 1463      72.684932              17          0        3               3
# 1464    1245.763158              32          2        7               7
# 1465   15779.666667              32          2        7               7
# 1466    5232.571429              24          0        5               5
# 1467  376460.000000              27          5        8               6
#
#       NumHDonors  NumHeteroatoms  NumRotatableBonds  NumValenceElectrons  \
# ...

# %%
sample_full.to_excel('sample_full.xlsx', index= False )

# %%
sample_full
# Out:
#                  SI  HeavyAtomCount  NHOHCount  NOCount  NumHAфcceptors  \
# 0        185.185185              14          1        2               2
# 1        638.571429              14          1        2               2
# 2         14.545455              18          0        2               2
# 3         60.240964              16          0        2               2
# 4          3.629442              17          0        3               3
# ...             ...             ...        ...      ...             ...
# 1463      72.684932              17          0        3               3
# 1464    1245.763158              32          2        7               7
# 1465   15779.666667              32          2        7               7
# 1466    5232.571429              24          0        5               5
# 1467  376460.000000              27          5        8               6
#
#       NumHDonors  NumHeteroatoms  NumRotatableBonds  NumValenceElectrons  \
# ...

# %%
sample_full.to_excel('sample_full.xlsx', index= False )

# %% [markdown]
# ## Получили две выборки:
# ### одна - для кластеризации (дальнейшей обработки данных)
# ### вторая - для регрессии, в которой мы не используем выбросы для более хороших моделей
